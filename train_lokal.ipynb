# %%
# !python train_lokal.py --yaml "tooth_lokal.yaml" --weight "checkpoint\weight_AP05_0.19_20_epoch.pth"
# Out:
# ^C
# Load yaml sucess...
# ...
# load weight from:checkpoint\weight_AP05_0.19_20_epoch.pth
# load param...
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 24, 80, 80]             648
#        BatchNorm2d-2           [-1, 24, 80, 80]              48
#               ReLU-3           [-1, 24, 80, 80]               0
#          MaxPool2d-4           [-1, 24, 40, 40]               0
#             Conv2d-5           [-1, 24, 20, 20]             216
#        BatchNorm2d-6           [-1, 24, 20, 20]              48
#             Conv2d-7           [-1, 24, 20, 20]             576
#        BatchNorm2d-8           [-1, 24, 20, 20]              48
#               ReLU-9           [-1, 24, 20, 20]               0
#            Conv2d-10           [-1, 24, 40, 40]             576
#       BatchNorm2d-11           [-1, 24, 40, 40]              48
# ...
